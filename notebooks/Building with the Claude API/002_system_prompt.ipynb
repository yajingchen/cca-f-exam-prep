# %% [markdown]
# # System Prompts

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# without system prompt
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat (messages)

answer
# Out:
# '# Solving 5x + 3 = 2\n\n**Step 1:** Subtract 3 from both sides\n$$5x + 3 - 3 = 2 - 3$$\n$$5x = -1$$\n\n**Step 2:** Divide both sides by 5\n$$x = -\\frac{1}{5}$$\n\nSo **x = -0.2** (or **-1/5** as a fraction)'

# %%
# after adding system prompt
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat (messages)

answer
# Out:
# "Great question! Let's work through this step by step.\n\nThe goal is to get **x by itself** on one side of the equation.\n\n**Step 1:** Look at what's with the x term.\n- You have 5x + 3 = 2\n- What number is being *added* to the 5x?\n\n**Step 2:** Think about how to remove that number.\n- What's the opposite operation of addition?\n- What would you do to both sides to remove the +3?\n\nOnce you try that, tell me what you get, and we'll move to the next step!"

# %%
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

# after adding system prompt
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat (messages, system=system)

answer
# Out:
# "Great question! Let's work through this step by step.\n\nThe goal is to get x by itself on one side of the equation.\n\n**Step 1:** Look at your equation: 5x + 3 = 2\n\nWhat do you think should be your first move? Think about what's being added to the 5x term, and how you could remove it."

# %%
# after adding system prompt
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat (messages)

answer
# Out:
# '# Solving 5x + 3 = 2\n\n**Step 1:** Subtract 3 from both sides\n$$5x + 3 - 3 = 2 - 3$$\n$$5x = -1$$\n\n**Step 2:** Divide both sides by 5\n$$x = -\\frac{1}{5}$$\n\n**Answer:** x = -0.2 (or -1/5)'

# %%
messages = []

add_user_message (
    messages,
    "Write a Python function that checks a string for duplicate characters.",
)

answer = chat(messages)

answer
# Out:
# '# Python Function to Check for Duplicate Characters\n\nHere are several approaches, from simple to more advanced:\n\n## 1. **Simple Approach Using Set**\n```python\ndef has_duplicates(s):\n    """\n    Check if a string has duplicate characters.\n    Returns True if duplicates found, False otherwise.\n    """\n    return len(s) != len(set(s))\n\n# Test cases\nprint(has_duplicates("hello"))      # True (two \'l\'s)\nprint(has_duplicates("python"))     # False\nprint(has_duplicates("aabbcc"))     # True\nprint(has_duplicates(""))           # False\n```\n\n## 2. **Detailed Version - Returns Duplicate Characters**\n```python\ndef find_duplicates(s):\n    """\n    Returns a set of duplicate characters found in the string.\n    """\n    seen = set()\n    duplicates = set()\n    \n    for char in s:\n        if char in seen:\n            duplicates.add(char)\n        else:\n            seen.add(char)\n    \n    return duplicates\n\n# Test cases\nprint(find_duplicates("hello"))      # {\'l\'}\nprint(find_duplicates("aabbcc"))     # {\'a\', \'b\', \'c\'}\nprint(find_duplicates("python"))     # set()\n```\n\n## 3. **Case-Insensitive Version**\n```python\ndef has_duplicates_ci(s, case_sensitive=True):\n    """\n    Check for duplicates with optional case-insensitivity.\n    """\n    if not case_sensitive:\n        s = s.lower()\n    \n    return len(s) != len(set(s))\n\n# Test cases\nprint(has_duplicates_ci("Hello"))           # False (case-sensitive)\nprint(has_duplicates_ci("Hello", False))    # True (case-insensitive)\n```\n\n## 4. **Version with Count Details**\n```python\ndef count_duplicates(s):\n    """\n    Returns a dictionary with character counts and duplicate info.\n    """\n    from collections import Counter\n    \n    char_count = Counter(s)\n    duplicates = {char: count for char, count in char_count.items() if count > 1}\n    \n    return {\n        \'has_duplicates\': bool(duplicates),\n        \'duplicate_chars\': duplicates,\n        \'total_chars\': len(s),\n        \'unique_chars\': len(char_count)\n    }\n\n# Test cases\nprint(count_duplicates("hello"))\n# Output: {\'has_duplicates\': True, \'duplicate_chars\': {\'l\': 2}, \'total_chars\': 5, \'unique_chars\': 4}\n\nprint(count_duplicates("aabbcc"))\n# Output: {\'has_duplicates\': True, \'duplicate_chars\': {\'a\': 2, \'b\': 2, \'c\': 2}, \'total_chars\': 6, \'unique_chars\': 3}\n```\n\n## 5. **Ignore Spaces/Special Characters**\n```python\ndef has_duplicates_alphanumeric(s):\n    """\n    Check for duplicates in alphanumeric characters only.\n    """\n    s_filtered = \'\'.join(c.lower() for c in s if c.isalnum())\n    return len(s_filtered) != len(set(s_filtered))\n\n# Test cases\nprint(has_duplicates_alphanumeric("Hello, World!"))  # True (two \'l\'s)\nprint(has_duplicates_alphanumeric("Hello, Python!")) # False\n```\n\n## **Performance Comparison**\n\n| Approach | Time Complexity | Space Complexity | Best For |\n|----------|-----------------|------------------|----------|\n| Set comparison | O(n) | O(n) | Simple check, small strings |\n| Counter | O(n) | O(n) | Detailed analysis |\n| Early exit (below) | O(n) | O(n) | Large strings |\n\n## 6. **Optimized with Early Exit**\n```python\ndef has_duplicates_optimized(s):\n    """\n    Exits early when first duplicate'

# %%
system="""
You are a Python engineer who writes very concise code.
Only respond with the code, no other text.
"""

messages = []

add_user_message (
    messages,
    "Write a Python function that checks a string for duplicate characters.",
)

answer = chat(messages, system=system)

answer
# Out:
# '\n```python\ndef has_duplicates(s: str) -> bool:\n    """Check if a string has duplicate characters."""\n    return len(s) != len(set(s))\n```'
